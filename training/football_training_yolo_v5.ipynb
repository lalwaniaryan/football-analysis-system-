# %%
# %pip install ultralytics
# %pip install roboflow
# Out:
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# ...
#   Using cached ultralytics_thop-2.0.15-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 16.6 MB/s eta 0:00:00
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 21.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/241.4 MB ? eta -:--:--
#     --------------------------------------- 5.2/241.4 MB 24.5 MB/s eta 0:00:10
# ...

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="xJs84VBC45iHPU3ivqvi")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(20)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-20 in yolov5pytorch:: 100%|██████████| 756/756 [00:00<00:00, 2541.90it/s]

# %%
dataset.location
# Out:
# 'c:\\Users\\Aryan Lalwani\\Downloads\\football_analysis-main\\football_analysis-main\\training\\football-players-detection-20'

# %%
import shutil

shutil.move('football-players-detection-20/train',
            'football-players-detection-20/football-players-detection-20/train'
            )

shutil.move('football-players-detection-20/test',
            'football-players-detection-20/football-players-detection-20/test'
            )

shutil.move('football-players-detection-20/valid',
            'football-players-detection-20/football-players-detection-20/valid'
            )
# Out:
# 'football-players-detection-20/football-players-detection-20/valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
